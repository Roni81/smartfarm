# %%
import pandas as pd
import numpy as np

# %%
df_cl = pd.read_csv('c:/users/user/data_cl.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17192\3191714907.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cl = pd.read_csv('c:/users/user/data_cl.csv')

# %%
df_cl = df_cl.drop(['기온 QC플래그','강수량 QC플래그',
            '풍향(16방위)','풍속 QC플래그',
            '풍향 QC플래그','습도 QC플래그','이슬점온도(°C)',
            '지면온도 QC플래그','증기압(hPa)','운형(운형약어)',
            '최저운고(100m )','시정(10m)',
            '현지기압 QC플래그','5cm 지중온도(°C)',
           '10cm 지중온도(°C)','20cm 지중온도(°C)',
           '30cm 지중온도(°C)','일사 QC플래그',
           '해면기압 QC플래그','일조 QC플래그',
           '전운량(10분위)','중하층운량(10분위)'], axis = 1)

# %%
df_cl.count()
# Out:
# date            4140799
# 지점              4140799
# 지점명             4140799
# 일시              4140799
# 기온(°C)          4136794
# 강수량(mm)          396152
# 풍속(m/s)         4132326
# 습도(%)           4135517
# 현지기압(hPa)       4136414
# 해면기압(hPa)       4136109
# 일조(hr)          2263054
# 일사(MJ/m2)       1104503
# 적설(cm)            83437
# 3시간신적설(cm)         3032
# 지면상태(지면상태코드)          0
# 현상번호(국내식)        275821
# 지면온도(°C)        4133420
# dtype: int64

# %%
df_cl[df_cl['기온(°C)'].isnull()]
# Out:
#                date   지점  지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  \
# 26802    2019-01-22   98  동두천  2019-01-22 18:00     NaN      NaN      NaN
# 30032    2019-06-06   98  동두천   2019-06-06 8:00     NaN      NaN      NaN
# 33205    2019-10-16   98  동두천  2019-10-16 13:00     NaN      NaN      NaN
# 33206    2019-10-16   98  동두천  2019-10-16 14:00     NaN      NaN      NaN
# 33207    2019-10-16   98  동두천  2019-10-16 15:00     NaN      NaN      NaN
# ...             ...  ...  ...               ...     ...      ...      ...
# 4112925  2023-09-04  288   밀양  2023-09-04 14:00     NaN      NaN      NaN
# 4112926  2023-09-04  288   밀양  2023-09-04 15:00     NaN      NaN      NaN
# 4115186  2023-12-07  288   밀양  2023-12-07 19:00     NaN      NaN      NaN
# 4138198  2023-09-01  295   남해  2023-09-01 15:00     NaN      0.0      0.4
# 4138199  2023-09-01  295   남해  2023-09-01 16:00     NaN      NaN      1.9
#
#          습도(%)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  3시간신적설(cm)  \
# ...

# %%
date_temp = df_cl['일시'].str.split(' ', expand = True)
date_temp.columns = ['date','time']
date_temp
# Out:
#                date   time
# 0        2019-01-01   0:00
# 1        2019-01-01   1:00
# 2        2019-01-01   2:00
# 3        2019-01-01   3:00
# 4        2019-01-01   4:00
# ...             ...    ...
# 4140794  2023-12-18  19:00
# 4140795  2023-12-18  20:00
# 4140796  2023-12-18  21:00
# 4140797  2023-12-18  22:00
# 4140798  2023-12-18  23:00
#
# [4140799 rows x 2 columns]

# %%
date_temp_0 = date_temp['date']
date_temp_0
# Out:
# 0          2019-01-01
# 1          2019-01-01
# 2          2019-01-01
# 3          2019-01-01
# 4          2019-01-01
#               ...
# 4140794    2023-12-18
# 4140795    2023-12-18
# 4140796    2023-12-18
# 4140797    2023-12-18
# 4140798    2023-12-18
# Name: date, Length: 4140799, dtype: object

# %%
df_cl = pd.concat([date_temp_0,df_cl],axis=1)

# %%
df_cl
# Out:
#                date   지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  \
# 0        2019-01-01   90  속초   2019-01-01 0:00    -2.5      NaN      0.8
# 1        2019-01-01   90  속초   2019-01-01 1:00    -1.9      NaN      0.6
# 2        2019-01-01   90  속초   2019-01-01 2:00    -2.2      NaN      1.4
# 3        2019-01-01   90  속초   2019-01-01 3:00    -2.5      NaN      1.4
# 4        2019-01-01   90  속초   2019-01-01 4:00    -3.9      NaN      0.5
# ...             ...  ...  ..               ...     ...      ...      ...
# 4140794  2023-12-18  295  남해  2023-12-18 19:00     0.9      NaN      0.4
# 4140795  2023-12-18  295  남해  2023-12-18 20:00     1.4      NaN      0.6
# 4140796  2023-12-18  295  남해  2023-12-18 21:00     0.9      NaN      1.0
# 4140797  2023-12-18  295  남해  2023-12-18 22:00     0.8      NaN      0.5
# 4140798  2023-12-18  295  남해  2023-12-18 23:00     0.8      NaN      0.9
#
#          습도(%)  현지기압(hPa)  해면기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  3시간신적설(cm)  \
# ...

# %%
df_mean = df_cl.groupby(['date','지점','지점명']).mean().reset_index().round(2)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17192\747625323.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_mean = df_cl.groupby(['date','지점','지점명']).mean().reset_index().round(2)

# %%
df_mean
# Out:
#               date   지점  지점명  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  현지기압(hPa)  \
# 0       2019-01-01   90   속초   -1.55      NaN     1.69  22.33    1026.38
# 1       2019-01-01   93  북춘천   -7.78      NaN     1.40  58.21    1020.85
# 2       2019-01-01   95   철원   -9.28      NaN     1.09  61.25    1013.91
# 3       2019-01-01   98  동두천   -6.98      NaN     1.70  46.88    1019.22
# 4       2019-01-01   99   파주   -8.24      NaN     1.03  64.79    1030.22
# ...            ...  ...  ...     ...      ...      ...    ...        ...
# 172530  2023-12-18  285   합천   -2.89      NaN     0.58  52.75    1030.50
# 172531  2023-12-18  288   밀양   -2.00      NaN     1.07  37.54    1032.31
# 172532  2023-12-18  289   산청   -3.27      NaN     1.86  58.67    1016.82
# 172533  2023-12-18  294   거제   -1.05      NaN     1.75  49.96    1027.77
# 172534  2023-12-18  295   남해   -1.52      NaN     1.05  57.21    1027.82
#
#         해면기압(hPa)  일조(hr)  일사(MJ/m2)  적설(cm)  3시간신적설(cm)  지면상태(지면상태코드)  \
# ...

# %%
date_split = df_mean['date'].str.split('-', expand = True)
date_split
# Out:
#            0   1   2
# 0       2019  01  01
# 1       2019  01  01
# 2       2019  01  01
# 3       2019  01  01
# 4       2019  01  01
# ...      ...  ..  ..
# 172530  2023  12  18
# 172531  2023  12  18
# 172532  2023  12  18
# 172533  2023  12  18
# 172534  2023  12  18
#
# [172535 rows x 3 columns]

# %%
df_mean = pd.concat([date_split,df_mean], axis = 1)

# %%
df_mean[df_mean['기온(°C)'].isnull()]
# Out:
#            0   1   2        date   지점  지점명  기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  \
# 19950   2019  07  29  2019-07-29  169  흑산도     NaN      NaN      NaN  98.50
# 20046   2019  07  30  2019-07-30  169  흑산도     NaN      NaN      NaN  97.92
# 22335   2019  08  23  2019-08-23  170   완도     NaN      NaN      NaN    NaN
# 22430   2019  08  24  2019-08-24  170   완도     NaN      NaN      NaN    NaN
# 32531   2019  12  08  2019-12-08  254  순창군     NaN      NaN      NaN    NaN
# 52207   2020  07  02  2020-07-02  268  진도군     NaN      NaN     1.20  82.62
# 86122   2021  06  24  2021-06-24  268  진도군     NaN      NaN     1.54  84.33
# 86217   2021  06  25  2021-06-25  268  진도군     NaN      NaN     1.85  81.62
# 86312   2021  06  26  2021-06-26  268  진도군     NaN      NaN     1.85  76.17
# 86407   2021  06  27  2021-06-27  268  진도군     NaN      NaN     1.46  78.25
# 86502   2021  06  28  2021-06-28  268  진도군     NaN     0.50     1.33  82.00
# ...

# %%
df_mean.info()
